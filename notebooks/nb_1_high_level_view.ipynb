# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier, plot_tree

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape, test.shape
# Out:
# ((187317, 12), (166801, 11))

# %%
train.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage'],
#       dtype='object')

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0    187.0
# 1   > 2 Years            Yes         58911.0                  26.0    288.0
# 2    < 1 Year             No         38043.0                 152.0    254.0
# 3    1-2 Year            Yes          2630.0                 156.0     76.0
# 4    1-2 Year             No         31951.0                 152.0    294.0
#
#    Response
# 0       0.0
# 1       1.0
# 2       0.0
# 3       0.0
# 4       0.0

# %%
test.head()
# Out:
#          id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  11504798  Female   20                1         47.0                   0
# 1  11504799    Male   47                1         28.0                   0
# 2  11504800    Male   47                1         43.0                   0
# 3  11504801  Female   22                1         47.0                   1
# 4  11504802    Male   51                1         19.0                   0
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No          2630.0                 160.0    228.0
# 1    1-2 Year            Yes         37483.0                 124.0    123.0
# 2    1-2 Year            Yes          2630.0                  26.0    271.0
# 3    < 1 Year             No         24502.0                 152.0    115.0
# 4    1-2 Year             No         34115.0                 124.0    148.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187317 entries, 0 to 187316
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    187317 non-null  int64
#  1   Gender                187317 non-null  object
#  2   Age                   187317 non-null  int64
#  3   Driving_License       187317 non-null  int64
#  4   Region_Code           187317 non-null  float64
#  5   Previously_Insured    187317 non-null  int64
#  6   Vehicle_Age           187317 non-null  object
#  7   Vehicle_Damage        187317 non-null  object
#  8   Annual_Premium        187316 non-null  float64
#  9   Policy_Sales_Channel  187316 non-null  float64
#  10  Vintage               187316 non-null  float64
#  11  Response              187316 non-null  float64
# dtypes: float64(5), int64(4), object(3)
# memory usage: 17.1+ MB

# %%
train['Response'].value_counts()
# Out:
# Response
# 0.0    164506
# 1.0     22810
# Name: count, dtype: int64

# %%
features = test.columns

dt = DecisionTreeClassifier(max_depth=3)
dt.fit(train[features], train['Response']);

plt.figure(figsize=(16, 6))
plot_tree(dt, feature_names=features, fontsize=7, impurity=False, filled=True, ax=plt.gca())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f08245e66e80> in <cell line: 4>()
#       2
#       3 dt = DecisionTreeClassifier(max_depth=3)
# ----> 4 dt.fit(train[features], train['Response']);
#       5
#       6 plt.figure(figsize=(16, 6))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#     957         """
#     958
# --> 959         super()._fit(
#     960             X,
#     961             y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     240             )
#     241             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 242             X, y = self._validate_data(
#     243                 X, y, validate_separately=(check_X_params, check_y_params)
#     244             )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     615                 if "estimator" not in check_X_params:
#     616                     check_X_params = {**default_check_params, **check_X_params}
# --> 617                 X = check_array(X, input_name="X", **check_X_params)
#     618                 if "estimator" not in check_y_params:
#     619                     check_y_params = {**default_check_params, **check_y_params}
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913                     array = xp.astype(array, dtype, copy=False)
#     914                 else:
# --> 915                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916             except ComplexWarning as complex_warning:
#     917                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     378             array = numpy.array(array, order=order, dtype=dtype)
#     379         else:
# --> 380             array = numpy.asarray(array, order=order, dtype=dtype)
#     381
#     382         # At this point array is a NumPy ndarray. We convert it to an array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#
# ValueError: could not convert string to float: 'Male'
